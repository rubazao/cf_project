# %%
import pandas as pd

# %%
df = pd.read_csv('games_2007_2020.csv')
# Out:
# c:\users\rubaz\projects\crossdata\ds_crossdata\cf_project\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (0,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#       overallScore overallRank countryChampion countryOfOriginName  \
# 0              272           1           False                 NaN
# 1              272           1           False                 NaN
# 2              272           1           False                 NaN
# 3              270           2           False                 NaN
# 4              270           2           False                 NaN
# ...            ...         ...             ...                 ...
# 36551        -42.0         129           False           Mauritius
# 36552        -42.0         129           False           Mauritius
# 36553        -42.0         129           False           Mauritius
# 36554        -42.0         129           False           Mauritius
# 36555        -42.0         129           False           Mauritius
#
#       countryOfOriginCode affiliateName firstName      lastName  \
# 0                     NaN           NaN     James    Fitzgerald
# ...

# %%
#Keep division 1 and 2 only
df_div = df[(df['division'] == 1) | (df['division'] == 2)]

# %%
#convert column competitorName to str
df_div['competitorName'] = df_div['competitorName'].astype(str)
# Out:
# <ipython-input-22-43ae1795e4b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_div['competitorName'] = df_div['competitorName'].astype(str)

# %%
#Remove Duplicates
df_div = df_div.drop_duplicates(['competitorName', 'year'])

# %%
df_div
# Out:
#       overallScore overallRank countryChampion countryOfOriginName  \
# 0              272           1           False                 NaN
# 3              270           2           False                 NaN
# 6              267           3           False                 NaN
# 9              261           4           False                 NaN
# 12              48           1           False                 NaN
# ...            ...         ...             ...                 ...
# 36496        -42.0         125           False            Botswana
# 36508        -42.0         126           False             Andorra
# 36520        -42.0         127           False              Serbia
# 36532        -42.0         128           False           Sri Lanka
# 36544        -42.0         129           False           Mauritius
#
#       countryOfOriginCode      affiliateName      firstName      lastName  \
# 0                     NaN                NaN          James    Fitzgerald
# ...

# %%
df_div[df_div['year'] == 2007]
# Out:
#      overallScore overallRank countryChampion countryOfOriginName  \
# 0             272           1           False                 NaN
# 3             270           2           False                 NaN
# 6             267           3           False                 NaN
# 9             261           4           False                 NaN
# 13            252           5           False                 NaN
# ...           ...         ...             ...                 ...
# 2144          121          39           False                 NaN
# 2206           85          40           False                 NaN
# 2294           59          41           False                 NaN
# 2470           85          43           False                 NaN
# 2566           56          44           False                 NaN
#
#      countryOfOriginCode affiliateName firstName    lastName  \
# 0                    NaN           NaN     James  Fitzgerald
# ...

# %%
#parsing column overallRank

#df_div['overallRank'] = df_div['overallRank'].astype(int)

# %%
pd.set_option('display.max_rows', 5000)
df_div['overallRank'].value_counts()
# Out:
# 15          28
# 2           28
# 3           28
# 5           28
# 8           28
# 13          28
# 12          28
# 7           28
# 6           28
# 10          28
# 18          28
# 16          28
# 20          28
# 9           28
# 14          28
# 11          28
# 19          28
# 1           28
# 17          28
# 4           28
# 28          27
# 23          27
# 21          27
# 29          27
# 26          27
# 24          27
# 22          27
# 27          27
# 25          27
# 30          27
# 32          25
# 35          25
# 36          25
# 33          25
# 31          25
# 34          25
# 37          24
# 38          24
# 39          23
# 40          21
# 41          16
# 42          15
# 43          15
# 44          13
# 45          11
# 46           9
# 47           7
# 48           6
# 49           6
# DQ           6
# 69           5
# 53           5
# 62           5
# 70           5
# 67           5
# 56           5
# 52           5
# 57           5
# ...

# %%
df_div['overallRank'].filter(regex=r'\D')
# Out:
# Series([], Name: overallRank, dtype: object)

# %%
df_div[df_div['overallRank'] == '1']
# Out:
#       overallScore overallRank countryChampion countryOfOriginName  \
# 0              272           1           False                 NaN
# 12              48           1           False                 NaN
# 16             915           1           False       United States
# 18             856           1           False       United States
# 23            1089           1           False                 NaN
# 27              78           1           False                 NaN
# 36             925           1           False                 NaN
# 37         13:17.0           1           False                 NaN
# 43             962           1           False                 NaN
# 70             290           1           False                 NaN
# 86         19:10.0           1           False                 NaN
# 106           1132           1             NaN                 NaN
# 131           1096           1           False       United States
# ...
